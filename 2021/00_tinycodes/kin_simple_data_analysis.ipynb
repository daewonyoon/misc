# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt

from io import StringIO

# %%
raw_data = """No.1,No.2
4.98,4.03
4.2,3.03
4.33,2.91
4.48,3.06
4.61,3.53
3.94,2.67
4.39,2.77
4.52,3.06
4.4,3.62
4.55,3.35
4.27,3.27
3.98,3.27
4.59,3.00
4.43,3.12
4.56,2.88
4.8,3.78
5.44,5.72
4.71,4.12
4.66,3.27
5.28,3.92
4.83,3.97
4.42,2.79
4.17,3.42
4.62,3.50
4.67,3.50
4.44,3.27
5.46,4.21
4.96,3.71
4.44,3.03"""

df = pd.read_csv(StringIO(raw_data))

df
# Out:
#     No.1  No.2
# 0   4.98  4.03
# 1   4.20  3.03
# 2   4.33  2.91
# 3   4.48  3.06
# 4   4.61  3.53
# 5   3.94  2.67
# 6   4.39  2.77
# 7   4.52  3.06
# 8   4.40  3.62
# 9   4.55  3.35
# 10  4.27  3.27
# 11  3.98  3.27
# 12  4.59  3.00
# 13  4.43  3.12
# 14  4.56  2.88
# 15  4.80  3.78
# 16  5.44  5.72
# 17  4.71  4.12
# 18  4.66  3.27
# 19  5.28  3.92
# 20  4.83  3.97
# 21  4.42  2.79
# 22  4.17  3.42
# 23  4.62  3.50
# 24  4.67  3.50
# 25  4.44  3.27
# 26  5.46  4.21
# 27  4.96  3.71
# 28  4.44  3.03

# %%
df.plot(grid=True)
# Out:
# <Axes: >

# %%
df["error"] = np.abs(df["No.2"] - df["No.1"])/df["No.1"] * 100

# %%
df2 = df.sort_values(by="No.1", ascending=True, ignore_index=True)

# %%
ax = df2.plot(grid=True, secondary_y=["error"])
ax.set_ylim(0, 6)
ax.right_ax.set_ylim(0, 100)
# Out:
# (0.0, 100.0)
