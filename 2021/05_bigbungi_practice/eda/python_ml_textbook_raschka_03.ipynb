# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

X = iris.data
y = iris.target

# %%
print(iris["DESCR"])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
X[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
y[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
df = pd.DataFrame(X, columns=["sepal_len", "sepal_width", "petal_len", "petal_width"])

# %%
df
# Out:
#      sepal_len  sepal_width  petal_len  petal_width
# 0          5.1          3.5        1.4          0.2
# 1          4.9          3.0        1.4          0.2
# 2          4.7          3.2        1.3          0.2
# 3          4.6          3.1        1.5          0.2
# 4          5.0          3.6        1.4          0.2
# ..         ...          ...        ...          ...
# 145        6.7          3.0        5.2          2.3
# 146        6.3          2.5        5.0          1.9
# 147        6.5          3.0        5.2          2.0
# 148        6.2          3.4        5.4          2.3
# 149        5.9          3.0        5.1          1.8
#
# [150 rows x 4 columns]

# %%
df["label"] = y

# %%
df
# Out:
#      sepal_len  sepal_width  petal_len  petal_width  label
# 0          5.1          3.5        1.4          0.2      0
# 1          4.9          3.0        1.4          0.2      0
# 2          4.7          3.2        1.3          0.2      0
# 3          4.6          3.1        1.5          0.2      0
# 4          5.0          3.6        1.4          0.2      0
# ..         ...          ...        ...          ...    ...
# 145        6.7          3.0        5.2          2.3      2
# 146        6.3          2.5        5.0          1.9      2
# 147        6.5          3.0        5.2          2.0      2
# 148        6.2          3.4        5.4          2.3      2
# 149        5.9          3.0        5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepal_len    150 non-null    float64
#  1   sepal_width  150 non-null    float64
#  2   petal_len    150 non-null    float64
#  3   petal_width  150 non-null    float64
#  4   label        150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
df.describe()
# Out:
#         sepal_len  sepal_width   petal_len  petal_width       label
# count  150.000000   150.000000  150.000000   150.000000  150.000000
# mean     5.843333     3.057333    3.758000     1.199333    1.000000
# std      0.828066     0.435866    1.765298     0.762238    0.819232
# min      4.300000     2.000000    1.000000     0.100000    0.000000
# 25%      5.100000     2.800000    1.600000     0.300000    0.000000
# 50%      5.800000     3.000000    4.350000     1.300000    1.000000
# 75%      6.400000     3.300000    5.100000     1.800000    2.000000
# max      7.900000     4.400000    6.900000     2.500000    2.000000

# %%
df.plot.scatter(x=0, y=1, c=4, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_len', ylabel='sepal_width'>

# %%
df.plot.scatter(x=1, y=2, c=4, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_len'>

# %%
df.plot.scatter(x=0, y=3, c=4, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_len', ylabel='petal_width'>

# %%
df.plot.scatter(x=0, y=2, c=4, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_len', ylabel='petal_len'>

# %%
df.plot.scatter(x=2, y=3, c=4, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='petal_len', ylabel='petal_width'>

# %%
df.plot.scatter(x=1, y=2, c=3, colormap="viridis")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_len'>
