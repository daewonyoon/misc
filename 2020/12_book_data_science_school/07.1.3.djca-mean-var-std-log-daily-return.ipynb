# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as web

# %%
sr = web.DataReader("DJCA", data_source="fred").dropna()["DJCA"]

sr
# Out:
# DATE
# 2015-12-10     6000.86
# 2015-12-11     5906.39
# 2015-12-14     5923.63
# 2015-12-15     5975.73
# 2015-12-16     6073.95
#                 ...
# 2020-11-30     9901.74
# 2020-12-01     9958.26
# 2020-12-02     9991.95
# 2020-12-03    10004.29
# 2020-12-04    10067.98
# Name: DJCA, Length: 1256, dtype: float64

# %%
sr.plot(grid=True)

# %%
r = np.log(sr/sr.shift(1)).dropna().values

# %%
r
# Out:
# array([-0.01586798,  0.00291462,  0.00875683, ...,  0.00337741,
#         0.00123423,  0.00634609])

# %%
print(f"평균 = {r.mean()}, 분산 = {r.var()}, 표준편차 = {r.std() }")
# Out:
# 평균 = 0.00041231657250126946, 분산 = 0.00015472932910600085, 표준편차 = 0.012439024443500417

# %%
df = sr.to_frame()

# %%
df["rate"] = r = np.log(sr/sr.shift(1))

# %%
#df.plot()
df.iloc[:, 1].plot(grid=True)
