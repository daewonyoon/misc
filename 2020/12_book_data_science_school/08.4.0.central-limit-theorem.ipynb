# %%
# 정규분포와 중심극한정리

# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats
import seaborn as sns

import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'D2Coding'

# %%
mu, std = 0, 1
rv = sp.stats.norm(mu, std)

# %%
xx = np.linspace(-5, 5, 100)
plt.grid(True)
plt.plot(xx, rv.pdf(xx))

plt.arrow(0, 0.05, 2, 0, lw=3, color='r', head_width=0.02, head_length=0.2, length_includes_head=True)
plt.arrow(0, 0.05, -2, 0, lw=3, color='r', head_width=0.02, head_length=0.2, length_includes_head=True)
plt.text(-0.95, 0.03, "표준편차의 약 4배")
# Out:
# Text(-0.95, 0.03, '표준편차의 약 4배')

# %%
np.random.seed(0)
x = rv.rvs(20)
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574])

# %%
ns, _ = np.histogram(x)
plt.grid(True)
plt.bar(x=list(range(10)), height=ns)
# Out:
# <BarContainer object of 10 artists>

# %%
sns.distplot(x, rug=True, fit=sp.stats.norm)
# Out:
# <AxesSubplot:ylabel='Density'>
